# %%
import pandas as pd

# %%
#Accessing pd_data from main notebook. Overwrite if others needed
# %store -r finalDataFrame

# %%
finalDataFrame
# Out:
#     Div       Date   Time        HomeTeam          AwayTeam FTHG FTAG FTR  \
# 0    E0 2019-09-08  20:00       Liverpool           Norwich    4    1   H
# 1    E0 2019-10-08  12:30        West Ham          Man City    0    5   A
# 2    E0 2019-10-08  15:00     Bournemouth  Sheffield United    1    1   D
# 3    E0 2019-10-08  15:00         Burnley       Southampton    3    0   H
# 4    E0 2019-10-08  15:00  Crystal Palace           Everton    0    0   D
# ..   ..        ...    ...             ...               ...  ...  ...  ..
# 457  E0 1994-07-05    NaN  Sheffield Weds          Man City    1    1   D
# 458  E0 1994-07-05    NaN         Swindon             Leeds    0    5   A
# 459  E0 1994-07-05    NaN       Tottenham               QPR    1    2   A
# 460  E0 1994-07-05    NaN        West Ham       Southampton    3    3   D
# 461  E0 1994-08-05    NaN      Man United          Coventry    0    0   D
#
#     HTHG HTAG  ... Attendance  HHW  AHW   HO   AO  HBP  ABP  SYH  SYD  SYA
# ...

# %%
# Current streak will display , for example as , 'WWWDL'. 
#Indicates 3 consecitive wins after a draw, which was preceded by a loss
